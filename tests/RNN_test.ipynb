# %%
import sys
import os
sys.path.insert(1, 'c:\\Users\\Vishal\\OneDrive - Texas Tech University\\lab-projects\\PeakSmoother\\PeakSmoother\\scripts')
import RNN
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_4502 = pd.read_csv("../sample_data/4502.csv")

# %%
smoothed_intensities = RNN.RNN(data_4502['Intensity'].values)
# Out:
# Epoch 1/100
# c:\Users\Vishal\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 0.1644
# Epoch 2/100
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0227
# Epoch 3/100
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0200
# Epoch 4/100
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0194
# Epoch 5/100
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0200
# Epoch 6/100
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0183
# Epoch 7/100
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0183
# Epoch 8/100
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0173
# Epoch 9/100
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0172
# Epoch 10/100
# ...

# %%
data_4502['Smoothed Intensity'] = smoothed_intensities
data_4502['Smoothed Intensity'] = data_4502['Smoothed Intensity'].clip(lower=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data_4502['Smoothed Intensity'] = smoothed_intensities
#       2 data_4502['Smoothed Intensity'] = data_4502['Smoothed Intensity'].clip(lower=0)
#
# File c:\Users\Vishal\anaconda3\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File c:\Users\Vishal\anaconda3\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
# ...

# %%
plt.figure(figsize=(10, 5))
plt.plot(data_4502['Intensity'], label='Original Intensity')
plt.plot(smoothed_intensities, label='Smoothed Intensity')

# %%
plt.plot(smoothed_intensities)

# %%
len(data_4502['Intensity'])
# Out:
# 12980
