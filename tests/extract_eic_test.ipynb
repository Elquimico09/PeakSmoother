# %%
import extract_eic

# %%
mzml_file = "../sample_data/Organelle_2_MGC.mzML"

# %%
import sys
import os
sys.path.insert(1, 'c:\\Users\\Vishal\\OneDrive - Texas Tech University\\lab-projects\\PeakSmoother\\PeakSmoother\\scripts')
import extract_eic

# %%
mzml_file = "../sample_data/Organelle_2_MGC.mzML"
data = extract_eic.extract_eic(mzml_file, 929.4828)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,3))
plt.plot(data['RT'], data['Intensity'], color = 'black', linewidth = 0.5)
plt.ylim(0, data['Intensity'].max() * 1.05)
plt.xlim(0, data['RT'].max())

plt.xlabel('Retention Time (min)')
plt.ylabel('Intensity')
# Out:
# Text(0, 0.5, 'Intensity')

# %%
data.to_csv('../sample_data/4502.csv', index = False)
